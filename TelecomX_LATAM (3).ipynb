# %% [markdown]
# #📌 Extracción

# %% [markdown]
# librerias base

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json')

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
from pandas import json_normalize

# %%
dato_normalizado = pd.json_normalize(datos)

# %%
dato_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Empty DataFrame

# %% [markdown]
# #🔧 Transformación

# %%
df_customer = datos['customer'].apply(pd.Series)
df_customer.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
# 3    Male              1     Yes         No      13
# 4  Female              1     Yes         No       3

# %%
# Expandir cada columna JSON en columnas separadas
df_customer = datos['customer'].apply(pd.Series)
df_phone = datos['phone'].apply(pd.Series)
df_internet = datos['internet'].apply(pd.Series)
df_account = datos['account'].apply(pd.Series)

# Unir todo en un solo DataFrame
df_final = pd.concat([datos.drop(['customer', 'phone', 'internet', 'account'], axis=1),
                      df_customer, df_phone, df_internet, df_account], axis=1)

print(df_final)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# ...

# %%
df_final.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df_charges = df_final['Charges'].apply(pd.Series)

# %%
df_final2 = pd.concat([df_final.drop(['Charges'], axis=1),
                      df_charges], axis=1)
df_final2.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_final2['Partner'] = df_final2['Partner'].map({'Yes': 1, 'No': 0})
df_final2['Dependents'] = df_final2['Dependents'].map({'Yes': 1, 'No': 0})
df_final2['PhoneService'] = df_final2['PhoneService'].map({'Yes': 1, 'No': 0})
df_final2['PaperlessBilling'] = df_final2['PaperlessBilling'].map({'Yes': 1, 'No': 0})
df_final2['Churn'] = df_final2['Churn'].map({'Yes': 1, 'No': 0})
df_final2['MultipleLines'] = df_final2['MultipleLines'].map({'Yes': 1, 'No': 0})
df_final2['OnlineSecurity'] = df_final2['OnlineSecurity'].map({'Yes': 1, 'No': 0})
df_final2['OnlineBackup'] = df_final2['OnlineBackup'].map({'Yes': 1, 'No': 0})
df_final2['DeviceProtection'] = df_final2['DeviceProtection'].map({'Yes': 1, 'No': 0})
df_final2['TechSupport'] = df_final2['TechSupport'].map({'Yes': 1, 'No': 0})
df_final2['StreamingTV'] = df_final2['StreamingTV'].map({'Yes': 1, 'No': 0})
df_final2['StreamingMovies'] = df_final2['StreamingMovies'].map({'Yes': 1, 'No': 0})

# %%
df_final.tail()
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7262          Yes                No             DSL            Yes
# 7263          Yes               Yes     Fiber optic             No
# 7264          Yes                No             DSL             No
# 7265          Yes                No             DSL            Yes
# 7266           No  No phone service             DSL            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# ...

# %%
df_final.tail()
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7262          Yes                No             DSL            Yes
# 7263          Yes               Yes     Fiber optic             No
# 7264          Yes                No             DSL             No
# 7265          Yes                No             DSL            Yes
# 7266           No  No phone service             DSL            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# ...

# %% [markdown]
# Diccionario de datos
#
# customerID: número de identificación único de cada cliente
#
# Churn: si el cliente dejó o no la empresa
#
# gender: género (masculino y femenino)
#
# SeniorCitizen: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
#
# Partner: si el cliente tiene o no una pareja
#
# Dependents: si el cliente tiene o no dependientes
#
# tenure: meses de contrato del cliente
#
# PhoneService: suscripción al servicio telefónico
#
# MultipleLines: suscripción a más de una línea telefónica
#
# InternetService: suscripción a un proveedor de internet
#
# OnlineSecurity: suscripción adicional de seguridad en línea
#
# OnlineBackup: suscripción adicional de respaldo en línea
#
# DeviceProtection: suscripción adicional de protección del dispositivo
#
# TechSupport: suscripción adicional de soporte técnico, menor tiempo de espera
#
# StreamingTV: suscripción de televisión por cable
#
# StreamingMovies: suscripción de streaming de películas
#
# Contract: tipo de contrato
#
# PaperlessBilling: si el cliente prefiere recibir la factura en línea
#
# PaymentMethod: forma de pago
#
# Charges.Monthly: total de todos los servicios del cliente por mes
#
# Charges.Total: total gastado por el cliente

# %% [markdown]
# ##Limpieza de datos
# Quita vacios

# %%
# Sacado de las mentoria script para verificar valores unicos de los campos
for col in df_final2.columns:
  print(f"valores únicos en la columna'{col}': {df_final2[col].nunique()}")
  if df_final2[col].nunique() < 50: # Imprima los valores solamente si no hay muchos
    print(df_final2[col].unique())
    print('-' * 50)  # Línea divisoria para mejor visualización
# Out:
# valores únicos en la columna'customerID': 7267
# valores únicos en la columna'Churn': 2
# [ 0.  1. nan]
# --------------------------------------------------
# valores únicos en la columna'gender': 2
# ['Female' 'Male']
# --------------------------------------------------
# valores únicos en la columna'SeniorCitizen': 2
# [0 1]
# --------------------------------------------------
# valores únicos en la columna'Partner': 2
# [1 0]
# --------------------------------------------------
# valores únicos en la columna'Dependents': 2
# [1 0]
# --------------------------------------------------
# valores únicos en la columna'tenure': 73
# valores únicos en la columna'PhoneService': 2
# [1 0]
# --------------------------------------------------
# valores únicos en la columna'MultipleLines': 2
# [ 0.  1. nan]
# --------------------------------------------------
# valores únicos en la columna'InternetService': 3
# ['DSL' 'Fiber optic' 'No']
# --------------------------------------------------
# ...

# %%
df_final2.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID           0
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Monthly              0
# Total               11
# dtype: int64

# %%
#Cambiando la columna "Total" a Float

df_final2['Total'] = pd.to_numeric(df_final2['Total'], errors='coerce')
print(df_final2['Total'].dtype)
# Out:
# float64

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ##Análisis Descriptivo

# %%
df_final2.describe()
# Out:
#              Churn  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7267.000000  7267.000000  7267.000000  7267.000000
# mean      0.265370       0.162653     0.484106     0.300124    32.346498
# std       0.441561       0.369074     0.499782     0.458343    24.571773
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       0.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  OnlineSecurity  OnlineBackup  \
# count   7267.000000    6560.000000     5686.000000   5686.000000
# mean       0.902711       0.467226        0.365459      0.440380
# std        0.296371       0.498963        0.481601      0.496476
# ...

# %%
# Vacíos o en blanco
df_final2.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Monthly             0
# Total               0
# dtype: int64

# %%
df_final2['Total'] = pd.to_numeric(df_final2['Total'], errors='coerce')
print(df_final2['Total'].dtype)
# Out:
# float64

# %%
df_final2['Cuentas_Diarias'] = df_final2['Monthly'] / 30
print(df_final2[['Monthly', 'Cuentas_Diarias']])
# Out:
#       Monthly  Cuentas_Diarias
# 0       65.60         2.186667
# 1       59.90         1.996667
# 2       73.90         2.463333
# 3       98.00         3.266667
# 4       83.90         2.796667
# ...       ...              ...
# 7262    55.15         1.838333
# 7263    85.10         2.836667
# 7264    50.30         1.676667
# 7265    67.85         2.261667
# 7266    59.00         1.966667
#
# [7267 rows x 2 columns]

# %%
df_final2 = df_final2.drop('Cuentas_Diarias', errors='ignore')

# %%
df_final2.head()
# Out:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO    0.0  Female            0.0      1.0         1.0     9.0
# 1  0003-MKNFE    0.0    Male            0.0      0.0         0.0     9.0
# 2  0004-TLHLJ    1.0    Male            0.0      0.0         0.0     4.0
# 3  0011-IGKFF    1.0    Male            1.0      1.0         0.0    13.0
# 4  0013-EXCHZ    1.0  Female            1.0      1.0         0.0     3.0
#
#    PhoneService  MultipleLines InternetService  ...  DeviceProtection  \
# 0           1.0            0.0             DSL  ...               0.0
# 1           1.0            1.0             DSL  ...               0.0
# 2           1.0            0.0     Fiber optic  ...               1.0
# 3           1.0            0.0     Fiber optic  ...               1.0
# 4           1.0            0.0     Fiber optic  ...               0.0
#
#    TechSupport  StreamingTV  StreamingMovies        Contract  \
# ...

# %% [markdown]
# #📄Informe final

# %%
import plotly.express as px
px.histogram(df_final2, x = 'gender', text_auto = True, color = 'Churn', barmode = 'group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Los hombres son los que mas se ha mantenido en la compañia con 2625 clientes masculinos, las que mas abandoron las compañoa son las mujeres ocn 939 clientas

# %%
px.histogram(df_final2, x = 'Contract', text_auto = True, color = 'Churn', barmode = 'group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# en el contrato mes a mes,es donde se tiene mayor posibilidad de que un cliente abandone la compañia siendo 1655/2220% la probavilidad de abandono, en el segundo año es muy baja la posiblidad de abandono siendo solo 48 casos sobre 1647 = 2,914% la probavlidad de abandono

# %%
px.histogram(df_final2, x = 'PaymentMethod',  text_auto = True, color = 'Churn', barmode = 'group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Lo clientes que abandonan la compañia la mayoria pagaba con el metodo elecronics check, los que menos, los clientes que pagaban via malied check son los que mas se han mantenido en la copañia
